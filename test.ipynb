# %%
import pandas as pd

# %%
AS = pd.read_csv('pose_coordinates_combined.csv')
AS.head(3)
# Out:
#                        mouth_right                       mouth_left  \
# 0  (0.510059, 0.383915, -0.288666)  (0.550476, 0.378674, -0.309148)
# 1  (0.511525, 0.382327, -0.347164)  (0.550555, 0.377644, -0.388698)
# 2  (0.515326, 0.384368, -0.398715)  (0.553316, 0.379689, -0.443637)
#
#                          RightHand                         LeftHand  \
# 0  (0.452543, 0.412272, -0.707126)  (0.573814, 0.416385, -0.661599)
# 1  (0.453925, 0.413413, -0.805831)  (0.574856, 0.419217, -0.746914)
# 2   (0.45716, 0.414756, -0.836242)   (0.58013, 0.425974, -0.798969)
#
#                       LeftShoulder                     RightForeArm  \
# 0   (0.668509, 0.40641, -0.111769)   (0.37441, 0.499476, -0.329376)
# 1   (0.67496, 0.407492, -0.222553)   (0.37562, 0.497577, -0.376136)
# 2  (0.686395, 0.409769, -0.272947)  (0.377514, 0.497536, -0.415994)
#
#                       LeftForeArm                    RightShoulder  \
# 0  (0.660384, 0.50643, -0.369763)  (0.417021, 0.402799, -0.042771)
# ...
